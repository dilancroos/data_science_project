# %% [markdown]
# ## Observing the files in the dataset
#
# season 2017/2018

# %%
#import the function from functions folder
from functions.functions import get_Normalized_DataFrame, get_DataFrame

# import the libraries
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# files the data folder

# %%
# get the files in the directory except for the __init__.py file and __pycache__ folder

filesInDir = os.listdir('data/')
filesInDir.remove('__init__.py')
filesInDir.remove('__pycache__')
filesInDir
# Out:
# ['referees.json',
#  'teams.json',
#  'competitions.json',
#  'playerank.json',
#  'players.json',
#  'coaches.json',
#  'tags2name.csv',
#  'eventid2name.csv']

# %% [markdown]
# ### Coaches

# %%
data = get_DataFrame('data/coaches.json')

# %%
# without normalization
coaches_df = pd.DataFrame(data)
print(coaches_df.shape)
coaches_df.head()
# Out:
# (208, 9)
#      wyId      shortName      firstName middleName         lastName  \
# 0  275580  Cesar Domingo  César Domingo             Mendiondo López
# 1   14710    J. Heynckes          Josef                    Heynckes
# 2  135480    G. De Biasi       Giovanni                    De Biasi
# 3  210074      Marcelino      Marcelino                García Toral
# 4  293398      T. Korkut         Tayfun                      Korkut
#
#     birthDate                                          birthArea  \
# 0        None  {'id': 76, 'alpha2code': 'BR', 'alpha3code': '...
# 1  1945-05-09  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
# 2  1956-06-16  {'id': 380, 'alpha2code': 'IT', 'alpha3code': ...
# 3  1965-08-14  {'id': 724, 'alpha2code': 'ES', 'alpha3code': ...
# 4  1974-04-02  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
#
#                                         passportArea  currentTeamId
# 0  {'id': 76, 'alpha2code': 'BR', 'alpha3code': '...              0
# ...

# %%
# with normalization

coaches_df_norm = get_Normalized_DataFrame('data/coaches.json')
print(coaches_df_norm.shape)
coaches_df_norm.head()
# Out:
# (208, 15)
#      wyId      shortName      firstName middleName         lastName  \
# 0  275580  Cesar Domingo  César Domingo             Mendiondo López
# 1   14710    J. Heynckes          Josef                    Heynckes
# 2  135480    G. De Biasi       Giovanni                    De Biasi
# 3  210074      Marcelino      Marcelino                García Toral
# 4  293398      T. Korkut         Tayfun                      Korkut
#
#     birthDate  currentTeamId  birthArea.id birthArea.alpha2code  \
# 0        None              0            76                   BR
# 1  1945-05-09              0           276                   DE
# 2  1956-06-16              0           380                   IT
# 3  1965-08-14            674           724                   ES
# 4  1974-04-02              0           276                   DE
#
#   birthArea.alpha3code birthArea.name  passportArea.id  \
# 0                  BRA         Brazil               76
# ...

# %% [markdown]
# ### Competitions

# %%
data = get_DataFrame('data/competitions.json')

# %%
# without normalization
competitions_df = pd.DataFrame(data)
print(competitions_df.shape)
competitions_df.head()
# Out:
# (7, 5)
#                      name  wyId           format  \
# 0  Italian first division   524  Domestic league
# 1  English first division   364  Domestic league
# 2  Spanish first division   795  Domestic league
# 3   French first division   412  Domestic league
# 4   German first division   426  Domestic league
#
#                                                 area  type
# 0  {'name': 'Italy', 'id': '380', 'alpha3code': '...  club
# 1  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'France', 'id': '250', 'alpha3code': ...  club
# 4  {'name': 'Germany', 'id': '276', 'alpha3code':...  club

# %%
# with normalization

competitions_df_norm = get_Normalized_DataFrame('data/competitions.json')
print(competitions_df_norm.shape)
competitions_df_norm
# Out:
# (7, 8)
#                      name  wyId             format           type area.name  \
# 0  Italian first division   524    Domestic league           club     Italy
# 1  English first division   364    Domestic league           club   England
# 2  Spanish first division   795    Domestic league           club     Spain
# 3   French first division   412    Domestic league           club    France
# 4   German first division   426    Domestic league           club   Germany
# 5   European Championship   102  International cup  international
# 6               World Cup    28  International cup  international
#
#   area.id area.alpha3code area.alpha2code
# 0     380             ITA              IT
# 1       0             XEN
# 2     724             ESP              ES
# 3     250             FRA              FR
# 4     276             DEU              DE
# 5       0             XEU
# 6       0             XWO

# %% [markdown]
# ### Event ID to Name

# %%
eventId2Name = pd.read_csv('data/eventid2name.csv')
print(eventId2Name.shape)
eventId2Name.head()
# Out:
# (36, 4)
#    event  subevent event_label          subevent_label
# 0      1        10        Duel                Air duel
# 1      1        11        Duel   Ground attacking duel
# 2      1        12        Duel   Ground defending duel
# 3      1        13        Duel  Ground loose ball duel
# 4      2        20        Foul                    Foul

# %% [markdown]
# ### Player Rank

# %%
data = get_DataFrame('data/playerank.json')

# %%
# without normalization
playerRank_df = pd.DataFrame(data)
print(playerRank_df.shape)
print(playerRank_df.head())
playerRank_df.sort_values(by=['playerankScore'], ascending=False).head(10) # top 10 players according to playerank score
# Out:
# (46897, 6)
#    goalScored  playerankScore  matchId  playerId roleCluster  minutesPlayed
# 0           0          0.0053  2057991     10014    right CB             90
# 1           0          0.0009  2057992     10014    right CB             41
# 2           0         -0.0013  2057998    100140  central MF             90
# 3           0          0.0031  2058000    100140     left CB             90
# 4           0          0.0035  2499869     10108    right CB             90
#        goalScored  playerankScore  matchId  playerId  \
# 12887           1          0.1731  2576059     21384
# 42223           0          0.1687  2565889      7972
# 35392           2          0.1666  2500862     40810
# 16603           0          0.1585  2500024    245364
# 10750           1          0.1528  2575999     20820
# 782             0          0.1524  2500078     11066
# 372             0          0.1520  2499970    105338
# 1517            0          0.1496  2576135       122
# ...

# %% [markdown]
# ### Players

# %%
data = get_DataFrame('data/players.json')

# %%
# without normalization
player_df = pd.DataFrame(data)
print(player_df.shape)
player_df.head()
# Out:
# (3603, 14)
#                                         passportArea  weight  \
# 0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...      78
# 1  {'name': 'Senegal', 'id': '686', 'alpha3code':...      73
# 2  {'name': 'France', 'id': '250', 'alpha3code': ...      72
# 3  {'name': 'Senegal', 'id': '686', 'alpha3code':...      82
# 4  {'name': 'France', 'id': '250', 'alpha3code': ...      84
#
#            firstName middleName     lastName currentTeamId   birthDate  \
# 0              Harun                   Tekin          4502  1989-06-17
# 1             Malang                    Sarr          3775  1999-01-23
# 2               Over                Mandanda          3772  1998-10-26
# 3  Alfred John Momar                 N'Diaye           683  1990-03-06
# 4           Ibrahima             Konat\u00e9          2975  1999-05-25
#
#    height                                               role  \
# 0     187  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# ...

# %%
# with normalization

player_df_norm = get_Normalized_DataFrame('data/players.json')
print(player_df_norm.shape)
player_df_norm.head()
# Out:
# (3603, 22)
#    weight          firstName middleName     lastName currentTeamId  \
# 0      78              Harun                   Tekin          4502
# 1      73             Malang                    Sarr          3775
# 2      72               Over                Mandanda          3772
# 3      82  Alfred John Momar                 N'Diaye           683
# 4      84           Ibrahima             Konat\u00e9          2975
#
#     birthDate  height    wyId   foot       shortName  ... passportArea.id  \
# 0  1989-06-17     187   32777  right        H. Tekin  ...             792
# 1  1999-01-23     182  393228   left         M. Sarr  ...             686
# 2  1998-10-26     176  393230            O. Mandanda  ...             250
# 3  1990-03-06     187   32793  right      A. N'Diaye  ...             686
# 4  1999-05-25     192  393247  right  I. Konat\u00e9  ...             250
#
#   passportArea.alpha3code passportArea.alpha2code role.code2 role.code3  \
# ...

# %% [markdown]
# ### Referees

# %%
data = get_DataFrame('data/referees.json')

# %%
# without normalization
referees_df = pd.DataFrame(data)
print(referees_df.shape)
referees_df.head()
# Out:
# (627, 8)
#      wyId   shortName  firstName middleName        lastName   birthDate  \
# 0  378217   A. Guzmán  Alexander             Guzmán Bonilla        None
# 1  385011  S. Bennett      Simon                    Bennett        None
# 2  385544   H. Osmers       Harm                     Osmers  1985-01-28
# 3  383894  F. Assmuth  Frederick                    Assmuth  1977-12-20
# 4  385800  F. Hebrard   Frédéric                    Hebrard        None
#
#                                            birthArea  \
# 0  {'id': 170, 'alpha2code': 'CO', 'alpha3code': ...
# 1  {'id': 826, 'alpha2code': 'EN', 'alpha3code': ...
# 2  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
# 3  {'id': 276, 'alpha2code': 'DE', 'alpha3code': ...
# 4  {'id': 250, 'alpha2code': 'FR', 'alpha3code': ...
#
#                                         passportArea
# 0  {'id': 170, 'alpha2code': 'CO', 'alpha3code': ...
# 1  {'id': 826, 'alpha2code': 'EN', 'alpha3code': ...
# ...

# %%
# with normalization

referees_df_norm = get_Normalized_DataFrame('data/referees.json')
print(referees_df_norm.shape)
referees_df_norm.head()
# Out:
# (627, 14)
#      wyId   shortName  firstName middleName        lastName   birthDate  \
# 0  378217   A. Guzmán  Alexander             Guzmán Bonilla        None
# 1  385011  S. Bennett      Simon                    Bennett        None
# 2  385544   H. Osmers       Harm                     Osmers  1985-01-28
# 3  383894  F. Assmuth  Frederick                    Assmuth  1977-12-20
# 4  385800  F. Hebrard   Frédéric                    Hebrard        None
#
#    birthArea.id birthArea.alpha2code birthArea.alpha3code birthArea.name  \
# 0           170                   CO                  COL       Colombia
# 1           826                   EN                  XEN        England
# 2           276                   DE                  DEU        Germany
# 3           276                   DE                  DEU        Germany
# 4           250                   FR                  FRA         France
#
#    passportArea.id passportArea.alpha2code passportArea.alpha3code  \
# ...

# %% [markdown]
# ### Tags to Name

# %%
df_tag2name = pd.read_csv('data/tags2name.csv')
print(df_tag2name.shape)
df_tag2name.head()
# Out:
# (59, 3)
#     Tag           Label     Description
# 0   101            Goal            Goal
# 1   102        own_goal        Own goal
# 2   301          assist          Assist
# 3   302         keyPass        Key pass
# 4  1901  counter_attack  Counter attack

# %% [markdown]
# ### Teams

# %%
data = get_DataFrame('data/teams.json')

# %%
# without normalization
teams_df = pd.DataFrame(data)
print(teams_df.shape)
teams_df.head()
# Out:
# (142, 6)
#                   city                   name  wyId  \
# 0  Newcastle upon Tyne       Newcastle United  1613
# 1                 Vigo          Celta de Vigo   692
# 2            Barcelona               Espanyol   691
# 3      Vitoria-Gasteiz  Deportivo Alav\u00e9s   696
# 4             Valencia                Levante   695
#
#                    officialName  \
# 0           Newcastle United FC
# 1       Real Club Celta de Vigo
# 2  Reial Club Deportiu Espanyol
# 3         Deportivo Alav\u00e9s
# 4                    Levante UD
#
#                                                 area  type
# 0  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 1  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 4  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club

# %%
# with normalization

teams_df_norm = get_Normalized_DataFrame('data/teams.json')
print(teams_df_norm.shape)
teams_df_norm.head()
# Out:
# (142, 9)
#                   city                   name  wyId  \
# 0  Newcastle upon Tyne       Newcastle United  1613
# 1                 Vigo          Celta de Vigo   692
# 2            Barcelona               Espanyol   691
# 3      Vitoria-Gasteiz  Deportivo Alav\u00e9s   696
# 4             Valencia                Levante   695
#
#                    officialName  type area.name area.id area.alpha3code  \
# 0           Newcastle United FC  club   England       0             XEN
# 1       Real Club Celta de Vigo  club     Spain     724             ESP
# 2  Reial Club Deportiu Espanyol  club     Spain     724             ESP
# 3         Deportivo Alav\u00e9s  club     Spain     724             ESP
# 4                    Levante UD  club     Spain     724             ESP
#
#   area.alpha2code
# 0
# 1              ES
# 2              ES
# 3              ES
# 4              ES
